# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect(r'./public.db')
def rsq(sql):
    return pd.read_sql(sql, conn)

# %%
-- Rename the university_shortname column
ALTER TABLE professors
RENAME COLUMN university_shortname TO university_id;
-- Add a foreign key on professors referencing universities
ALTER TABLE professors
ADD CONSTRAINT professors_fkey FOREIGN KEY (university_id) REFERENCES universities (id);

# %%
rsq("""-- Rename the university_shortname column
ALTER TABLE professors
RENAME COLUMN university_shortname TO university_id;""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/1486661822.py in <module>
# ----> 1 rsq("""-- Rename the university_shortname column
#       2 ALTER TABLE professors
#       3 RENAME COLUMN university_shortname TO university_id;""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ----> 5     return pd.read_sql(sql, conn)
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652     with pandasSQL_builder(con) as pandas_sql:
#     653         if isinstance(pandas_sql, SQLiteDatabase):
# --> 654             return pandas_sql.read_query(
# ...

# %%
rsq("""-- Add a foreign key on professors referencing universities
ALTER TABLE professors
ADD CONSTRAINT professors_fkey FOREIGN KEY (university_id) REFERENCES universities (id);""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: near "CONSTRAINT": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/2612680295.py in <module>
# ----> 1 rsq("""-- Add a foreign key on professors referencing universities
#       2 ALTER TABLE professors
#       3 ADD CONSTRAINT professors_fkey FOREIGN KEY (university_id) REFERENCES universities (id);""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
# ...

# %%
rsq("""-- Try to insert a new professor
INSERT INTO professors (firstname, lastname, university_id)
VALUES ('Albert', 'Einstein', 'UZH');""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/1591030682.py in <module>
# ----> 1 rsq("""-- Try to insert a new professor
#       2 INSERT INTO professors (firstname, lastname, university_id)
#       3 VALUES ('Albert', 'Einstein', 'UZH');""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ----> 5     return pd.read_sql(sql, conn)
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652     with pandasSQL_builder(con) as pandas_sql:
#     653         if isinstance(pandas_sql, SQLiteDatabase):
# --> 654             return pandas_sql.read_query(
# ...

# %%
rsq("""-- Rename the university_shortname column
ALTER TABLE universities
RENAME COLUMN university_shortname TO id;""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/740014314.py in <module>
# ----> 1 rsq("""-- Rename the university_shortname column
#       2 ALTER TABLE universities
#       3 RENAME COLUMN university_id TO id;""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ----> 5     return pd.read_sql(sql, conn)
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652     with pandasSQL_builder(con) as pandas_sql:
#     653         if isinstance(pandas_sql, SQLiteDatabase):
# --> 654             return pandas_sql.read_query(
#     655                 sql,
# ...

# %%
rsq("""-- Select all professors working for universities in the city of Zurich
SELECT professors.lastname, universities.id, universities.university_city
FROM professors
JOIN universities
ON professors.university_id = universities.id
WHERE universities.university_city = 'Zurich';""")
# Out:
#       lastname   id university_city
# 0       Abhari  ETH          Zurich
# 1     Axhausen  ETH          Zurich
# 2     Baschera  ETH          Zurich
# 3        Basin  ETH          Zurich
# 4     Bechtold  ETH          Zurich
# 5   Boutellier  ETH          Zurich
# 6       Capkun  ETH          Zurich
# 7     Carreira  ETH          Zurich
# 8      Ermanni  ETH          Zurich
# 9        Faist  ETH          Zurich
# 10     Fontana  ETH          Zurich
# 11    Frossard  ETH          Zurich
# 12    Gramazio  ETH          Zurich
# 13       Gross  ETH          Zurich
# 14       Grote  ETH          Zurich
# 15      Gruber  ETH          Zurich
# 16    Gruissem  ETH          Zurich
# 17      Nelson  ETH          Zurich
# 18        Neri  ETH          Zurich
# 19     Tröster  ETH          Zurich
# 20       Vogel  ETH          Zurich
# 21     Wegener  ETH          Zurich
# 22   von Krogh  ETH          Zurich
# 23      Bühler  UZH          Zurich
# 24    Einstein  UZH          Zurich
# ...

# %%
-- Add a professor_id column
ALTER TABLE affiliations
ADD COLUMN professor_id integer REFERENCES professors (id);

-- Rename the organization column to organization_id
ALTER TABLE affiliations
RENAME organization TO organization_id;

-- Add a foreign key on organization_id
ALTER TABLE affiliations
ADD CONSTRAINT affiliations_organization_fkey FOREIGN KEY (organization_id) REFERENCES organizations (id);

# %%
rsq("""-- Add a professor_id column
ALTER TABLE affiliations
ADD COLUMN professor_id integer REFERENCES professors (id);""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/295496145.py in <module>
# ----> 1 rsq("""-- Add a professor_id column
#       2 ALTER TABLE affiliations
#       3 ADD COLUMN professor_id integer REFERENCES professors (id);""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ----> 5     return pd.read_sql(sql, conn)
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652     with pandasSQL_builder(con) as pandas_sql:
#     653         if isinstance(pandas_sql, SQLiteDatabase):
# --> 654             return pandas_sql.read_query(
#     655                 sql,
# ...

# %%
rsq("""
-- Rename the organization column to organization_id
ALTER TABLE affiliations
RENAME organization TO organization_id;

""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/2428961431.py in <module>
# ----> 1 rsq("""
#       2 -- Rename the organization column to organization_id
#       3 ALTER TABLE affiliations
#       4 RENAME organization TO organization_id;
#       5
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ----> 5     return pd.read_sql(sql, conn)
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652     with pandasSQL_builder(con) as pandas_sql:
#     653         if isinstance(pandas_sql, SQLiteDatabase):
# --> 654             return pandas_sql.read_query(
# ...

# %%
rsq("""
-- Add a foreign key on organization_id
ALTER TABLE affiliations
ADD CONSTRAINT affiliations_organization_fkey FOREIGN KEY (organization_id) REFERENCES organizations (id);""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: near "CONSTRAINT": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3200934777.py in <module>
# ----> 1 rsq("""
#       2 -- Add a foreign key on organization_id
#       3 ALTER TABLE affiliations
#       4 ADD CONSTRAINT affiliations_organization_fkey FOREIGN KEY (organization_id) REFERENCES organizations (id);""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
# ...

# %%
rsq("""-- Have a look at the 10 first rows of affiliations
SELECT * FROM affiliations LIMIT 10;""")
# Out:
#    id        firstname     lastname  \
# 0   1             Karl       Aberer
# 1   2             Karl       Aberer
# 2   3             Karl       Aberer
# 3   4             Karl       Aberer
# 4   5  Reza Shokrollah       Abhari
# 5   6          Georges  Abou Jaoudé
# 6   7           Hugues       Abriel
# 7   8           Daniel    Aebersold
# 8   9           Daniel    Aebersold
# 9  10           Daniel    Aebersold
#
#                                             function  \
# 0                     Chairman of L3S Advisory Board
# 1   Member Conseil of Zeno-Karl Schindler Foundation
# 2                  Member of Conseil Fondation IDIAP
# 3                                      Panel Member
# 4                                Aufsichtsratsmandat
# 5  Professeur invité (2 interventions d'une semaine)
# 6                                               None
# 7                                               None
# 8                                               None
# ...

# %%
rsq("""-- Update professor_id to professors.id where firstname, lastname correspond to rows in professors
UPDATE affiliations
SET professor_id = professors.id
FROM professors
WHERE affiliations.firstname = professors.firstname AND affiliations.lastname = professors.lastname;""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3577380269.py in <module>
# ----> 1 rsq("""-- Update professor_id to professors.id where firstname, lastname correspond to rows in professors
#       2 UPDATE affiliations
#       3 SET professor_id = professors.id
#       4 FROM professors
#       5 WHERE affiliations.firstname = professors.firstname AND affiliations.lastname = professors.lastname;""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ----> 5     return pd.read_sql(sql, conn)
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
rsq("""-- Have a look at the 10 first rows of affiliations again
SELECT * FROM affiliations LIMIT 10;""")
# Out:
#    id        firstname     lastname  \
# 0   1             Karl       Aberer
# 1   2             Karl       Aberer
# 2   3             Karl       Aberer
# 3   4             Karl       Aberer
# 4   5  Reza Shokrollah       Abhari
# 5   6          Georges  Abou Jaoudé
# 6   7           Hugues       Abriel
# 7   8           Daniel    Aebersold
# 8   9           Daniel    Aebersold
# 9  10           Daniel    Aebersold
#
#                                             function  \
# 0                     Chairman of L3S Advisory Board
# 1   Member Conseil of Zeno-Karl Schindler Foundation
# 2                  Member of Conseil Fondation IDIAP
# 3                                      Panel Member
# 4                                Aufsichtsratsmandat
# 5  Professeur invité (2 interventions d'une semaine)
# 6                                               None
# 7                                               None
# 8                                               None
# ...

# %%
# -- Drop the firstname column
# ALTER TABLE affiliations
# DROP COLUMN firstname;

# -- Drop the lastname column
# ALTER TABLE affiliations
# DROP COLUMN lastname;

# %%
-- Identify the correct constraint name
SELECT constraint_name, table_name, constraint_type
FROM information_schema.table_constraints
WHERE constraint_type = 'FOREIGN KEY';

-- Drop the right foreign key constraint
ALTER TABLE affiliations
DROP CONSTRAINT affiliations_organization_id_fkey;

-- Add a new foreign key constraint from affiliations to organizations which cascades deletion
ALTER TABLE affiliations
ADD CONSTRAINT affiliations_organization_id_fkey FOREIGN KEY (organization_id) REFERENCES organizations (id) ON DELETE CASCADE;

-- Delete an organization
DELETE FROM organizations
WHERE id = 'CUREM';

-- Check that no more affiliations with this organization exist
SELECT * FROM affiliations
WHERE organization_id = 'CUREM';

# %%
rsq("""-- Identify the correct constraint name
SELECT constraint_name, table_name, constraint_type
FROM information_schema.table_constraints
WHERE constraint_type = 'FOREIGN KEY';""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such table: information_schema.table_constraints
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/1097097022.py in <module>
# ----> 1 rsq("""-- Identify the correct constraint name
#       2 SELECT constraint_name, table_name, constraint_type
#       3 FROM information_schema.table_constraints
#       4 WHERE constraint_type = 'FOREIGN KEY';""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
# ...

# %%
rsq("""-- Check that no more affiliations with this organization exist
SELECT * FROM affiliations
WHERE organization_id = 'CUREM'""")
# Out:
#     id firstname lastname       function organization_id  professor_id
# 0  314    Roland     Füss  Lehrtätigkeit           CUREM           126

# %%
rsq("""-- Delete an organization
DELETE FROM organizations
WHERE id = 'CUREM';""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such column: id
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/2369352673.py in <module>
# ----> 1 rsq("""-- Delete an organization
#       2 DELETE FROM organizations
#       3 WHERE id = 'CUREM';""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ----> 5     return pd.read_sql(sql, conn)
#
# ...

# %%
rsq("""-- Check that no more affiliations with this organization exist
SELECT * FROM affiliations
WHERE organization_id = 'CUREM'""")
# Out:
#     id firstname lastname       function organization_id  professor_id
# 0  314    Roland     Füss  Lehrtätigkeit           CUREM           126

# %%
rsq("""
    -- Join all tables
SELECT *
FROM affiliations
JOIN professors
ON affiliations.professor_id = professors.id
JOIN organizations
ON affiliations.organization = organizations.organization
JOIN universities
ON professors.university_id = universities.id;
    """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such column: affiliations.organization
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/192466798.py in <module>
# ----> 1 rsq("""
#       2     -- Join all tables
#       3 SELECT *
#       4 FROM affiliations
#       5 JOIN professors
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_40976/3457203818.py in rsq(sql)
#       3 conn = sqlite3.connect(r'./public.db')
#       4 def rsq(sql):
# ...

# %%
rsq("""-- Filter the table and sort it
SELECT COUNT(*), organizations.organization_sector,
professors.id, universities.university_city
FROM affiliations
JOIN professors
ON affiliations.professor_id = professors.id
JOIN organizations
ON affiliations.organization_id = organizations.id
JOIN universities
ON professors.university_id = universities.id
WHERE organizations.organization_sector = 'Media & communication'
GROUP BY organizations.organization_sector,
professors.id, universities.university_city
ORDER BY COUNT DESC;""")
