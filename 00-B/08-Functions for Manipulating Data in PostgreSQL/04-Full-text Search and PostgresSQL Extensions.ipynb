# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

conn = sqlite3.connect('./example.db')
def rsq(sql):
    df = pd.read_sql(sql, conn)
    return df

# %%
rsq("""-- Select all columns
SELECT *
FROM film
-- Select only records that begin with the word 'GOLD'
WHERE title LIKE 'GOLD%';""")
# Out:
#    film_id                   title  \
# 0      365              GOLD RIVER
# 1      366  GOLDFINGER SENSIBILITY
# 2      367         GOLDMINE TYCOON
#
#                                          description  release_year  \
# 0  A Taut Documentary of a Database Administrator...          2006
# 1  A Insightful Drama of a Mad Scientist And a Hu...          2006
# 2  A Brilliant Epistle of a Composer And a Frisbe...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                     1                4         4.99     154
# 1            1                     1                3         0.99      93
# 2            1                     1                6         0.99     153
#
#    replacement_cost rating          last_update  \
# 0             21.99      R  2006-02-15 05:03:00
# 1             29.99      G  2006-02-15 05:03:00
# 2             20.99      R  2006-02-15 05:03:00
#
# ...

# %%
rsq("""SELECT *
FROM film
-- Select only records that end with the word 'GOLD'
WHERE title like '%GOLD';""")
# Out:
#    film_id       title                                        description  \
# 0      644  OSCAR GOLD  A Insightful Tale of a Database Administrator ...
# 1      870  SWARM GOLD  A Insightful Panorama of a Crocodile And a Boa...
#
#    release_year  language_id  original_language_id  rental_duration  \
# 0          2006            1                     1                7
# 1          2006            1                     1                4
#
#    rental_rate  length  replacement_cost rating          last_update  \
# 0         2.99     115             29.99     PG  2006-02-15 05:03:00
# 1         0.99     123             12.99  PG-13  2006-02-15 05:03:00
#
#         special_features
# 0      Behind the Scenes
# 1  Trailers,Commentaries

# %%
rsq("""SELECT *
FROM film
-- Select only records that contain the word 'GOLD'
WHERE title LIKE '%GOLD%';""").drop_duplicates()
# Out:
#     film_id                   title  \
# 0       365              GOLD RIVER
# 1        95    BREAKFAST GOLDFINGER
# 2       366  GOLDFINGER SENSIBILITY
# 3       367         GOLDMINE TYCOON
# 4         2          ACE GOLDFINGER
# 17      644              OSCAR GOLD
# 18      798    SILVERADO GOLDFINGER
# 19      870              SWARM GOLD
#
#                                           description  release_year  \
# 0   A Taut Documentary of a Database Administrator...          2006
# 1   A Beautiful Reflection of a Student And a Stud...          2006
# 2   A Insightful Drama of a Mad Scientist And a Hu...          2006
# 3   A Brilliant Epistle of a Composer And a Frisbe...          2006
# 4   A Astounding Epistle of a Database Administrat...          2006
# 17  A Insightful Tale of a Database Administrator ...          2006
# 18  A Stunning Epistle of a Sumo Wrestler And a Ma...          2006
# 19  A Insightful Panorama of a Crocodile And a Boa...          2006
#
# ...

# %%
rsq("""-- Select the title and description
SELECT title, description
FROM film
-- Convert the title to a tsvector and match it against the tsquery 
WHERE title @@ to_tsquery('elf');
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: unrecognized token: "@"
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/1611103620.py in <module>
# ----> 1 rsq("""-- Select the title and description
#       2 SELECT title, description
#       3 FROM film
#       4 -- Convert the title to a tsvector and match it against the tsquery
#       5 WHERE title @@ to_tsquery('elf');
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
# ...

# %%
rsq("""-- Select the title and description
SELECT title, description
FROM film
-- Convert the title to a string and match it against the search criteria
WHERE title LIKE '%' || 'elf' || '%' ; """)
# Out:
#               title                                        description
# 0  GHOSTBUSTERS ELF  A Thoughtful Epistle of a Dog And a Feminist w...
# 1        ELF MURDER  A Action-Packed Story of a Frisbee And a Woman...
# 2        ENCINO ELF  A Astounding Drama of a Feminist And a Teacher...
# 3  GHOSTBUSTERS ELF  A Thoughtful Epistle of a Dog And a Feminist w...

# %%
-- Create an enumerated data type, compass_position
CREATE TYPE compass_position AS ENUM (
  	-- Use the four cardinal directions
  	'North', 
  	'South',
  	'East', 
  	'West'
);
-- Confirm the new data type is in the pg_type system table
SELECT *
FROM pg_type
WHERE typname='compass_position';

# %%
rsq("""-- Create a table with a check constraint to enforce the enumerated values
CREATE TABLE compass_position (
    position TEXT CHECK(position IN ('North', 'South', 'East', 'West'))
);""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/998240047.py in <module>
# ----> 1 rsq("""-- Create a table with a check constraint to enforce the enumerated values
#       2 CREATE TABLE compass_position (
#       3     position TEXT CHECK(position IN ('North', 'South', 'East', 'West'))
#       4 );
#       5
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ----> 8     df = pd.read_sql(sql, conn)
#       9     return df
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652     with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
rsq("""-- Confirm the new table is in the sqlite_master table
SELECT *
FROM sqlite_master
WHERE type = 'table' AND name = 'compass_position';""")
# Out:
#     type              name          tbl_name  rootpage  \
# 0  table  compass_position  compass_position        61
#
#                                                  sql
# 0  CREATE TABLE compass_position (\n    position ...

# %%
-- Select the film description as a tsvector
SELECT to_tsvector(description)
FROM film;

# %%
def rsq(sql):
    df = pd.read_sql(sql, conn)
    if df.empty:
        return pd.DataFrame(columns=df.columns)
    else:
        return df

# %%
rsq("""-- Convert PostgreSQL specific syntax to SQLite syntax
-- Select the film description as a FTS5 table
SELECT description_fts FROM film_fts;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such column: description_fts
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/2851776889.py in <module>
# ----> 1 rsq("""-- Convert PostgreSQL specific syntax to SQLite syntax
#       2 -- Select the film description as a FTS5 table
#       3 SELECT description_fts FROM film_fts;""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3069526006.py in rsq(sql)
#       1 def rsq(sql):
# ...

# %%
rsq("""-- Select the column name, data type and udt name columns
SELECT column_name, data_type, udt_name
FROM INFORMATION_SCHEMA.COLUMNS 
-- Filter by the rating column in the film table
WHERE table_name ='film' AND column_name='rating';""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such table: INFORMATION_SCHEMA.COLUMNS
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/4264599449.py in <module>
# ----> 1 rsq("""-- Select the column name, data type and udt name columns
#       2 SELECT column_name, data_type, udt_name
#       3 FROM INFORMATION_SCHEMA.COLUMNS
#       4 -- Filter by the rating column in the film table
#       5 WHERE table_name ='film' AND column_name='rating';""")
#
# ...

# %%
rsq("""
-- Select the column name, data type and udt name columns 
SELECT name, type
FROM pragma_table_info('film') 
-- Filter by the rating column in the film table 
WHERE name = 'rating'""")
# Out:
#      name  type
# 0  rating  TEXT

# %%
rsq("""SELECT * FROM pg_type WHERE typname = 'mpaa_rating';""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such table: pg_type
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3391030261.py in <module>
# ----> 1 rsq("""SELECT * FROM pg_type WHERE typname = 'mpaa_rating';""")
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ----> 8     df = pd.read_sql(sql, conn)
#       9     return df
#
# ...

# %%
rsq("""PRAGMA table_info('film');""")
# Out:
#     cid                  name     type  notnull dflt_value  pk
# 0     0               film_id  INTEGER        0       None   0
# 1     1                 title     TEXT        0       None   0
# 2     2           description     TEXT        0       None   0
# 3     3          release_year  INTEGER        0       None   0
# 4     4           language_id  INTEGER        0       None   0
# 5     5  original_language_id  INTEGER        0       None   0
# 6     6       rental_duration  INTEGER        0       None   0
# 7     7           rental_rate     REAL        0       None   0
# 8     8                length  INTEGER        0       None   0
# 9     9      replacement_cost     REAL        0       None   0
# 10   10                rating     TEXT        0       None   0
# 11   11           last_update     TEXT        0       None   0
# 12   12      special_features     TEXT        0       None   0

# %%
rsq("""-- Select the film title and inventory ids
SELECT 
	f.title, 
    i.inventory_id,
    -- Determine whether the inventory is held by a customer
    inventory_held_by_customer(i.inventory_id) AS held_by_cust
FROM film as f 
	INNER JOIN inventory AS i ON f.film_id=i.film_id;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: inventory_held_by_customer
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/2584698345.py in <module>
# ----> 1 rsq("""-- Select the film title and inventory ids
#       2 SELECT
#       3         f.title,
#       4     i.inventory_id,
#       5     -- Determine whether the inventory is held by a customer
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
# ...

# %%
-- Select the film title and inventory ids
SELECT 
	f.title, 
    i.inventory_id,
    -- Determine whether the inventory is held by a customer
    inventory_held_by_customer(i.inventory_id) as held_by_cust
FROM film as f 
	INNER JOIN inventory AS i ON f.film_id=i.film_id 
WHERE
	-- Only include results where the held_by_cust is not null
    inventory_held_by_customer(i.inventory_id) IS NOT NULL

# %%
rsq("""CREATE FUNCTION add_numbers(x INTEGER, y INTEGER) RETURNS INTEGER AS '
BEGIN
  DECLARE sum INTEGER;
  SET sum = x + y;
  RETURN sum;
END;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: near "FUNCTION": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3980190230.py in <module>
# ----> 1 rsq("""CREATE FUNCTION inventory_held_by_customer(x INTEGER) RETURNS INTEGER AS $$
#       2 BEGIN
#       3   DECLARE sum INTEGER;
#       4   SET sum = x
#       5   RETURN sum
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
# ...

# %%
rsq("""-- Select the film title and inventory ids
SELECT 
	f.title, 
    i.inventory_id,
    -- Determine whether the inventory is held by a customer
    inventory_held_by_customer(i.inventory_id) as held_by_cust
FROM film as f 
	INNER JOIN inventory AS i ON f.film_id=i.film_id 
WHERE
	-- Only include results where the held_by_cust is not null
    inventory_held_by_customer(i.inventory_id) IS NOT NULL""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: inventory_held_by_customer
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/379505397.py in <module>
# ----> 1 rsq("""-- Select the film title and inventory ids
#       2 SELECT
#       3         f.title,
#       4     i.inventory_id,
#       5     -- Determine whether the inventory is held by a customer
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
# ...

# %%
-- Enable the pg_trgm extension
CREATE EXTENSION IF NOT EXISTS pg_trgm;

# %%
In SQLite, there is no need to enable extensions as all available extensions are already pre-loaded. So you can just remove that line of code and write your SQL queries directly. 

For example, to create a table in SQLite, you can use the following code:

```
CREATE TABLE IF NOT EXISTS some_table (
   id INTEGER PRIMARY KEY,
   name TEXT,
   age INTEGER
);
```

Similarly, you can insert data into the table using the `INSERT INTO` statement:

```
INSERT INTO some_table (name, age) VALUES ('John Doe', 30);
```

And retrieve data from the table using the `SELECT` statement:

```
SELECT * FROM some_table;
```

Just remember to adjust your syntax and queries based on SQLite's SQL syntax and available functions.

# %%
-- Select all rows extensions
SELECT * 
FROM pg_extension;

# %%
rsq("""SELECT *
FROM sqlite_master
WHERE type = 'table';""")
# Out:
#     type              name          tbl_name  rootpage  \
# 0  table              film              film         2
# 1  table            rental            rental        35
# 2  table          customer          customer        38
# 3  table             actor             actor        42
# 4  table         inventory         inventory        43
# 5  table     film_category     film_category        50
# 6  table          category          category        51
# 7  table           address           address        52
# 8  table  compass_position  compass_position        61
#
#                                                  sql
# 0  CREATE TABLE "film" (\n"film_id" INTEGER,\n  "...
# 1  CREATE TABLE "rental" (\n"rental_id" INTEGER,\...
# 2  CREATE TABLE "customer" (\n"customer_id" INTEG...
# 3  CREATE TABLE "actor" (\n"actor_id" INTEGER,\n ...
# 4  CREATE TABLE "inventory" (\n"inventory_id" INT...
# 5  CREATE TABLE "film_category" (\n"film_id" INTE...
# ...

# %%
rsq("""-- Select the title and description columns
SELECT 
  title, 
  description, 
  -- Calculate the similarity
  SIMILARITY(title, description)
FROM 
  film""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: SIMILARITY
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/1259274387.py in <module>
# ----> 1 rsq("""-- Select the title and description columns
#       2 SELECT
#       3   title,
#       4   description,
#       5   -- Calculate the similarity
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
rsq("""-- Select the title and description columns
SELECT 
  title, 
  description, 
  -- Calculate the similarity
  (length(title) + length(description)) - levenshtein(title, description) as similarity
FROM 
  film;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: levenshtein
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/76234108.py in <module>
# ----> 1 rsq("""-- Select the title and description columns
#       2 SELECT
#       3   title,
#       4   description,
#       5   -- Calculate the similarity
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
-- Select the title and description columns
SELECT 
  title, 
  description, 
  -- Calculate the levenshtein distance
  levenshtein(title, 'JET NEIGHBOR') AS distance
FROM 
  film
ORDER BY 3

# %%
import %pip install editdistance
editdistance

rsq("""-- Select the title and description columns
SELECT 
    title, 
    description, 
    -- Calculate the levenshtein distance
    (? - editdistance(title, 'JET NEIGHBOR')) AS distance
FROM 
    film
ORDER BY 3;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: editdistance
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/2696362169.py in <module>
#       3 import editdistance
#       4
# ----> 5 rsq("""-- Select the title and description columns
#       6 SELECT
#       7     title,
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
SELECT  
  title,  
  description,  
  similarity(description, 'Astounding Drama') AS sim  
FROM  
  film  
WHERE  
  description MATCH 'Astounding AND Drama'  
ORDER BY  
  sim DESC;

# %%
rsq("""SELECT  
    title,  
    description,  
    similarity(description, 'Astounding Drama') AS sim  
FROM  
    film  
WHERE  
    description MATCH 'Astounding AND Drama'  
ORDER BY  
    sim DESC;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: similarity
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/2898865961.py in <module>
# ----> 1 rsq("""SELECT
#       2     title,
#       3     description,
#       4     similarity(description, 'Astounding Drama') AS sim
#       5 FROM
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_36120/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...
