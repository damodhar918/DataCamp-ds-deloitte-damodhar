# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

conn = sqlite3.connect('./example.db')
def rsq(sql):
    df = pd.read_sql(sql, conn)
    return df

# %%
rsq("""SELECT * FROM CROSSTAB($$
  SELECT
    Gender, Year, Country
  FROM Summer_Medals
  WHERE
    Year IN (2008, 2012)
    AND Medal = 'Gold'
    AND Event = 'Pole Vault'
  ORDER By Gender ASC, Year ASC
-- Fill in the correct column names for the pivoted table
$$) AS ct (Gender VARCHAR,
           "2008" VARCHAR,
          "2012" VARCHAR)

ORDER BY Gender ASC;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: near "SELECT": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/640341462.py in <module>
# ----> 1 rsq("""SELECT * FROM CROSSTAB($$
#       2   SELECT
#       3     Gender, Year, Country
#       4   FROM Summer_Medals
#       5   WHERE
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
rsq("""-- Count the gold medals per country and year
SELECT
  Country,
  Year,
  COUNT(*) AS Awards
FROM Summer_Medals
WHERE
  Country IN ('FRA', 'GBR', 'GER')
  AND Year IN (2004, 2008, 2012)
  AND Medal = 'Gold'
GROUP BY Country, Year
ORDER BY Country ASC, Year ASC""")
# Out:
#   Country  Year  Awards
# 0     FRA  2004      21
# 1     FRA  2008      25
# 2     FRA  2012      30
# 3     GBR  2004      17
# 4     GBR  2008      31
# 5     GBR  2012      48
# 6     GER  2004      41
# 7     GER  2008      42
# 8     GER  2012      45

# %%
rsq("""WITH Country_Awards AS (
  SELECT
    Country,
    Year,
    COUNT(*) AS Awards
  FROM Summer_Medals
  WHERE
    Country IN ('FRA', 'GBR', 'GER')
    AND Year IN (2004, 2008, 2012)
    AND Medal = 'Gold'
  GROUP BY Country, Year)

SELECT
  Country,
  Year,
  -- Rank by gold medals earned per year
  RANK() OVER
    (PARTITION BY Year
     ORDER BY Awards DESC) AS rank
FROM Country_Awards
ORDER BY Country ASC, Year ASC;""")
# Out:
#   Country  Year  rank
# 0     FRA  2004     2
# 1     FRA  2008     3
# 2     FRA  2012     3
# 3     GBR  2004     3
# 4     GBR  2008     2
# 5     GBR  2012     1
# 6     GER  2004     1
# 7     GER  2008     1
# 8     GER  2012     2

# %%
rsq("""WITH Country_Awards AS (
    SELECT
      Country,
      Year,
      COUNT(*) AS Awards
    FROM Summer_Medals
    WHERE
      Country IN ('FRA', 'GBR', 'GER')
      AND Year IN (2004, 2008, 2012)
      AND Medal = 'Gold'
    GROUP BY Country, Year)

  SELECT
    Country,
    Year,
    RANK() OVER
      (PARTITION BY Year
       ORDER BY Awards DESC) AS rank
  FROM Country_Awards
  ORDER BY Country ASC, Year ASC;""")
# Out:
#   Country  Year  rank
# 0     FRA  2004     2
# 1     FRA  2008     3
# 2     FRA  2012     3
# 3     GBR  2004     3
# 4     GBR  2008     2
# 5     GBR  2012     1
# 6     GER  2004     1
# 7     GER  2008     1
# 8     GER  2012     2

# %%
rsq("""WITH Country_Awards AS (
    SELECT
        Country,
        Year,
        COUNT(*) AS Awards
    FROM Summer_Medals
    WHERE
        Country IN ('FRA', 'GBR', 'GER')
        AND Year IN (2004, 2008, 2012)
        AND Medal = 'Gold'
    GROUP BY Country, Year)

SELECT
    Country,
    Year,
    -- Rank by gold medals earned per year
    RANK() OVER
        (PARTITION BY Year
         ORDER BY Awards DESC) CAST() AS INTEGER) AS rank
FROM Country_Awards
ORDER BY Country ASC, Year ASC;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: near "(": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/1186595257.py in <module>
# ----> 1 rsq("""WITH Country_Awards AS (
#       2     SELECT
#       3         Country,
#       4         Year,
#       5         COUNT(*) AS Awards
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
rsq("""CREATE EXTENSION IF NOT EXISTS tablefunc;

SELECT * FROM CROSSTAB($$
  WITH Country_Awards AS (
    SELECT
      Country,
      Year,
      COUNT(*) AS Awards
    FROM Summer_Medals
    WHERE
      Country IN ('FRA', 'GBR', 'GER')
      AND Year IN (2004, 2008, 2012)
      AND Medal = 'Gold'
    GROUP BY Country, Year)

  SELECT
    Country,
    Year,
    RANK() OVER
      (PARTITION BY Year
       ORDER BY Awards DESC) :: INTEGER AS rank
  FROM Country_Awards
  ORDER BY Country ASC, Year ASC;
-- Fill in the correct column names for the pivoted table
$$) AS ct (Country VARCHAR,
           "2004" INTEGER,
           "2008" INTEGER,
           "2012" INTEGER)

Order by Country ASC;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: near "EXTENSION": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/395283599.py in <module>
# ----> 1 rsq("""CREATE EXTENSION IF NOT EXISTS tablefunc;
#       2
#       3 SELECT * FROM CROSSTAB($$
#       4   WITH Country_Awards AS (
#       5     SELECT
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
rsq("""CREATE EXTENSION IF NOT EXISTS tablefunc;

SELECT * FROM CROSSTAB($$
  WITH Country_Awards AS (
    SELECT
      Country,
      Year,
      COUNT(*) AS Awards
    FROM Summer_Medals
    WHERE
      Country IN ('FRA', 'GBR', 'GER')
      AND Year IN (2004, 2008, 2012)
      AND Medal = 'Gold'
    GROUP BY Country, Year)

  SELECT
    Country,
    Year,
    RANK() OVER
      (PARTITION BY Year
       ORDER BY Awards DESC) :: INTEGER AS rank
  FROM Country_Awards
  ORDER BY Country ASC, Year ASC;
-- Fill in the correct column names for the pivoted table
$$) AS ct (Country VARCHAR,
           "2004" INTEGER,
           "2008" INTEGER,
           "2012" INTEGER)

Order by Country ASC;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: near "EXTENSION": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/395283599.py in <module>
# ----> 1 rsq("""CREATE EXTENSION IF NOT EXISTS tablefunc;
#       2
#       3 SELECT * FROM CROSSTAB($$
#       4   WITH Country_Awards AS (
#       5     SELECT
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
rsq("""-- Count the medals per gender and medal type
SELECT
  Gender,
  Medal,
  COUNT(*) AS Awards
FROM Summer_Medals
WHERE
  Year = 2012
  AND Country = 'RUS'
-- Get all possible group-level subtotals
GROUP BY CUBE(Gender, Medal)
ORDER BY Gender ASC, Medal ASC;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: CUBE
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/828515690.py in <module>
# ----> 1 rsq("""-- Count the medals per gender and medal type
#       2 SELECT
#       3   Gender,
#       4   Medal,
#       5   COUNT(*) AS Awards
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
rsq("""WITH Country_Medals AS (
  SELECT
    Country,
    COUNT(*) AS Medals
  FROM Summer_Medals
  WHERE Year = 2000
    AND Medal = 'Gold'
  GROUP BY Country)

  SELECT
    Country,
    -- Rank countries by the medals awarded
    RANK() OVER (ORDER BY Medals DESC) AS Rank
  FROM Country_Medals
  ORDER BY Rank ASC;""")
# Out:
#    Country  Rank
# 0      USA     1
# 1      RUS     2
# 2      AUS     3
# 3      CHN     4
# 4      GER     5
# 5      NED     6
# 6      ROU     6
# 7      HUN     8
# 8      CUB     9
# 9      FRA     9
# 10     GBR     9
# 11     ITA     9
# 12     NOR    13
# 13     CMR    14
# 14     DEN    14
# 15     KOR    16
# 16     YUG    16
# 17     POL    18
# 18     BAH    19
# 19     BUL    20
# 20     JPN    20
# 21     CAN    22
# 22     ETH    22
# 23     GRE    22
# 24     SWE    22
# 25     AUT    26
# 26     BLR    26
# 27     ESP    26
# 28     FIN    26
# 29     IRI    26
# 30     KAZ    26
# 31     SLO    26
# 32     TUR    26
# 33     UKR    26
# 34     AZE    35
# 35     CZE    35
# 36     INA    35
# 37     KEN    35
# 38     LTU    35
# 39     SVK    35
# 40     ALG    41
# 41     COL    41
# 42     CRO    41
# 43     EST    41
# 44     LAT    41
# 45     MEX    41
# 46     MOZ    41
# 47     NZL    41
# 48     SUI    41
# 49     THA    41
# 50     UZB    41

# %%
rsq("""SELECT
  -- Replace the nulls in the columns with meaningful text
  COALESCE(Country, 'All countries') AS Country,
  COALESCE(Gender, 'All genders') AS Gender,
  COUNT(*) AS Awards
FROM Summer_Medals
WHERE
  Year = 2004
  AND Medal = 'Gold'
  AND Country IN ('DEN', 'NOR', 'SWE')
GROUP BY ROLLUP(Country, Gender)
ORDER BY Country ASC, Gender ASC;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: ROLLUP
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/526043784.py in <module>
# ----> 1 rsq("""SELECT
#       2   -- Replace the nulls in the columns with meaningful text
#       3   COALESCE(Country, 'All countries') AS Country,
#       4   COALESCE(Gender, 'All genders') AS Gender,
#       5   COUNT(*) AS Awards
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/3855461635.py in rsq(sql)
# ...

# %%
rsq("""WITH Country_Medals AS (
  SELECT
    Country,
    COUNT(*) AS Medals
  FROM Summer_Medals
  WHERE Year = 2000
    AND Medal = 'Gold'
  GROUP BY Country),

  Country_Ranks AS (
  SELECT
    Country,
    RANK() OVER (ORDER BY Medals DESC) AS Rank
  FROM Country_Medals
  ORDER BY Rank ASC)

-- Compress the countries column
SELECT STRING_AGG(Country, ', ')
FROM Country_Ranks
-- Select only the top three ranks
WHERE Rank <= 3;""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py in execute(self, sql, params)
#    2263         try:
# -> 2264             cur.execute(sql, *args)
#    2265             return cur
#
# OperationalError: no such function: STRING_AGG
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/2233494741.py in <module>
# ----> 1 rsq("""WITH Country_Medals AS (
#       2   SELECT
#       3     Country,
#       4     COUNT(*) AS Medals
#       5   FROM Summer_Medals
#
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_24876/3855461635.py in rsq(sql)
#       6 conn = sqlite3.connect('./example.db')
#       7 def rsq(sql):
# ...

# %%
rsq("""WITH Country_Medals AS (
  SELECT
    Country,
    COUNT(*) AS Medals
  FROM Summer_Medals
  WHERE Year = 2000
    AND Medal = 'Gold'
  GROUP BY Country),

  Country_Ranks AS (
  SELECT
    Country,
    RANK() OVER (ORDER BY Medals DESC) AS Rank
  FROM Country_Medals
  ORDER BY Rank ASC)

-- Compress the countries column
SELECT group_concat(Country, ', ')
FROM Country_Ranks
-- Select only the top three ranks
WHERE Rank <= 3;""")
# Out:
#   group_concat(Country, ', ')
# 0               USA, RUS, AUS
