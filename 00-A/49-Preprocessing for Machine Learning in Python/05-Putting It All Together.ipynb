# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
ufo = pd.read_csv('./ufo_sightings_large.csv')

# %%
# Print the DataFrame info
print(ufo.info())

# Change the type of seconds to float
ufo["seconds"] = ufo["seconds"].astype(float)

# Change the date column to type datetime
ufo["date"] = pd.to_datetime(ufo["date"])

# Check the column types
print(ufo.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4935 entries, 0 to 4934
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4935 non-null   object
#  1   city            4926 non-null   object
#  2   state           4516 non-null   object
#  3   country         4255 non-null   object
#  4   type            4776 non-null   object
#  5   seconds         4935 non-null   float64
#  6   length_of_time  4792 non-null   object
#  7   desc            4932 non-null   object
#  8   recorded        4935 non-null   object
#  9   lat             4935 non-null   object
#  10  long            4935 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 424.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4935 entries, 0 to 4934
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4935 non-null   datetime64[ns]
#  1   city            4926 non-null   object
#  2   state           4516 non-null   object
#  3   country         4255 non-null   object
#  4   type            4776 non-null   object
#  5   seconds         4935 non-null   float64
#  6   length_of_time  4792 non-null   object
#  7   desc            4932 non-null   object
#  8   recorded        4935 non-null   object
#  9   lat             4935 non-null   object
#  10  long            4935 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 424.2+ KB
# None

# %%
# Count the missing values in the length_of_time, state, and type columns, in that order
print(ufo[['length_of_time', 'state', 'type']].isna().sum())

# Drop rows where length_of_time, state, or type are missing
ufo_no_missing = ufo.dropna(subset=['length_of_time', 'state', 'type'])

# Print out the shape of the new dataset
print(ufo_no_missing.shape)
# Out:
# length_of_time    143
# state             419
# type              159
# dtype: int64
# (4283, 11)

# %%
import re
def return_minutes(time_string):
    # Search for numbers in time_string
    num = re.search('\d+', time_string)
    if num is not None:
        return int(num.group(0))
        
# Apply the extraction to the length_of_time column
ufo["length_of_time"] = ufo["length_of_time"].astype('str').apply(lambda x: x if 'minute' in x.lower() else None)
ufo = ufo.dropna(subset=['length_of_time'])
ufo["minutes"] = ufo["length_of_time"].astype('str').apply(return_minutes)

# Take a look at the head of both of the columns

print(ufo[["length_of_time", "minutes"]].head())
# Out:
#      length_of_time  minutes
# 3   about 5 minutes      5.0
# 5        10 minutes     10.0
# 8         2 minutes      2.0
# 9         2 minutes      2.0
# 10        5 minutes      5.0

# %%
# Check the variance of the seconds and minutes columns
print(ufo[["seconds", "minutes"]].var())

# Log normalize the seconds column
ufo["seconds_log"] = np.log(ufo["seconds"])

# Print out the variance of just the seconds_log column
print(ufo["seconds_log"].var())
# Out:
# seconds    425466.767742
# minutes       118.377156
# dtype: float64
# 1.135245689687893

# %%
# Use pandas to encode us values as 1 and others as 0
ufo["country_enc"] = ufo["country"].apply(lambda x: 1 if x == "us" else 0)

# Print the number of unique type values
print(len(ufo["type"].unique()))

# Create a one-hot encoded set of the type values
type_set = pd.get_dummies(ufo["type"])

# Concatenate this set back to the ufo DataFrame
ufo = pd.concat([ufo, type_set], axis=1)
# Out:
# 22

# %%
# Look at the first 5 rows of the date column
print(ufo["date"].head()) 

# Extract the month from the date column
ufo["month"] = pd.DatetimeIndex(ufo["date"]).month

# Extract the year from the date column
ufo["year"] = pd.DatetimeIndex(ufo["date"]).year

# Take a look at the head of all three columns
print(ufo[["date", "month", "year"]].head())
# Out:
# 3    2002-11-21 05:45:00
# 5    2012-06-16 23:00:00
# 8    2013-06-09 00:00:00
# 9    2013-04-26 23:27:00
# 10   2013-09-13 20:30:00
# Name: date, dtype: datetime64[ns]
#                   date  month  year
# 3  2002-11-21 05:45:00     11  2002
# 5  2012-06-16 23:00:00      6  2012
# 8  2013-06-09 00:00:00      6  2013
# 9  2013-04-26 23:27:00      4  2013
# 10 2013-09-13 20:30:00      9  2013

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
# Take a look at the head of the desc field
print(ufo['desc'].head())

# Instantiate the tfidf vectorizer object
vec = TfidfVectorizer()

# Fit and transform desc using vec
desc_tfidf = vec.fit_transform(ufo['desc'])

# Look at the number of columns and rows

print(desc_tfidf.shape)
# Out:
# 3     It was a large&#44 triangular shaped flying ob...
# 5     Dancing lights that would fly around and then ...
# 8     Brilliant orange light or chinese lantern at o...
# 9     Bright red light moving north to north west fr...
# 10    North-east moving south-west. First 7 or so li...
# Name: desc, dtype: object
# (2013, 3597)

# %%
# Add in the rest of the arguments
def return_weights(vocab, original_vocab, vector, vector_index, top_n):
    zipped = dict(zip(vector[vector_index].indices, vector[vector_index].data))
    
    # Transform that zipped dict into a series
    zipped_series = pd.Series({vocab[i]:zipped[i] for i in vector[vector_index].indices})
    
    # Sort the series to pull out the top n weighted words
    zipped_index = zipped_series.sort_values(ascending=False)[:top_n].index
    return [original_vocab[i] for i in zipped_index]

# Print out the weighted words
# print(return_weights(vocab, tfidf_vec.vocabulary_, text_tfidf, 8, 3))

# %%
def words_to_filter(vocab, original_vocab, vector, top_n):
    filter_list = []
    for i in range(0, vector.shape[0]):
    
        # Call the return_weights function and extend filter_list
        filtered = return_weights(vocab, original_vocab, vector, i, top_n)
        filter_list.extend(filtered)
        
    # Return the list in a set, so we don't get duplicate word indices
    return set(filter_list)

# Call the function to get the list of word indices

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# volunteer = ufo.dropna(subset=['category_desc'])

# Take the title text
title_text = ufo["desc"]
# Create the vectorizer method
tfidf_vec = TfidfVectorizer()

# Transform the text into tf-idf vectors

text_tfidf = tfidf_vec.fit_transform(title_text)

# %%
# Make a list of features to drop   
to_drop = ["city", "country", "date", "desc", "lat", "length_of_time", "long", "minutes", "recorded", "seconds", "state"]

# Drop those features
ufo_dropped = ufo.drop(to_drop, axis=1)
vocab = {v: k for k, v in tfidf_vec.vocabulary_.items()}

# Let's also filter some words out of the text vector we created
filtered_words = words_to_filter(vocab, vec.vocabulary_, desc_tfidf, 4)
vocab
# Out:
# {1748: 'it',
#  3444: 'was',
#  1840: 'large',
#  155: '44',
#  3282: 'triangular',
#  2794: 'shaped',
#  1376: 'flying',
#  2248: 'object',
#  951: 'dancing',
#  1891: 'lights',
#  3158: 'that',
#  3552: 'would',
#  1375: 'fly',
#  414: 'around',
#  358: 'and',
#  3163: 'then',
#  2028: 'merge',
#  1723: 'into',
#  2289: 'one',
#  1884: 'light',
#  631: 'brilliant',
#  2305: 'orange',
#  2301: 'or',
#  753: 'chinese',
#  1834: 'lantern',
#  431: 'at',
#  1871: 'less',
#  3157: 'than',
#  15: '1000',
#  1421: 'ft',
#  2130: 'moving',
#  1149: 'east',
#  3207: 'to',
#  3467: 'west',
#  289: 'across',
#  2244: 'oakville',
#  2292: 'ontario',
#  2049: 'midnight',
#  1781: 'june',
#  266: '9th',
#  95: '2013',
#  623: 'bright',
#  2597: 'red',
#  2211: 'north',
#  1418: 'from',
#  3159: 'the',
#  1611: 'horizon',
#  3198: 'till',
#  1046: 'disapeared',
#  526: 'behind',
#  803: 'clouds',
#  2935: 'south',
#  1331: 'first',
#  2907: 'so',
#  912: 'craft',
#  1526: 'half',
#  1109: 'dozen',
#  3045: 'stragglers',
#  3172: 'they',
#  3465: 'were',
#  3092: 'surely',
#  2221: 'not',
#  2449: 'planes',
#  2208: 'nor',
#  472: 'ball',
#  2272: 'of',
#  2891: 'slowly',
#  3018: 'stationary',
#  2140: 'multicolored',
#  774: 'circular',
#  2032: 'met',
#  664: 'by',
#  369: 'another',
#  3486: 'which',
#  2560: 'raised',
#  2020: 'meet',
#  3215: 'too',
#  1070: 'displayed',
#  3312: 'ufo',
#  1482: 'going',
#  2875: 'sky',
#  3370: 'uso',
#  3449: 'watched',
#  3366: 'us',
#  1387: 'for',
#  903: 'couple',
#  2071: 'minutes',
#  1382: 'follows',
#  3244: 'train',
#  3236: 'tracks',
#  1680: 'in',
#  3522: 'winter',
#  48: '1931',
#  2718: 'saw',
#  1961: 'machine',
#  420: 'as',
#  2652: 'riding',
#  2287: 'on',
#  1615: 'horse',
#  1111: 'draw',
#  2383: 'pasture',
#  13: '10',
#  2462: 'pm',
#  23: '12',
#  264: '99',
#  2737: 'scottsdale',
#  404: 'arizona',
#  2919: 'something',
#  1548: 'have',
#  2179: 'never',
#  2759: 'seen',
#  522: 'before',
#  3256: 'traveling',
#  274: 'above',
#  1474: 'glow',
#  720: 'central',
#  2096: 'montana',
#  2034: 'metalic',
#  2965: 'sphere',
#  2679: 'rotating',
#  1291: 'fast',
#  2389: 'pattern',
#  3456: 'we',
#  1122: 'driving',
#  3227: 'town',
#  3167: 'there',
#  1740: 'is',
#  1485: 'golf',
#  904: 'course',
#  1600: 'holes',
#  796: 'close',
#  2663: 'road',
#  3483: 'when',
#  331: 'all',
#  3103: 'suuden',
#  2380: 'passing',
#  3084: 'sunday',
#  101: '21st',
#  2764: 'semptember',
#  90: '2008',
#  112: '30',
#  2188: 'night',
#  1638: 'huge',
#  2258: 'observed',
#  1134: 'during',
#  2189: 'nightime',
#  1894: 'like',
#  1204: 'entire',
#  779: 'city',
#  2058: 'millions',
#  1765: 'jetplanes',
#  1393: 'formation',
#  2198: 'no',
#  2930: 'sound',
#  3296: 'turned',
#  2273: 'off',
#  497: 'bayou',
#  583: 'blvd',
#  2293: 'onto',
#  1481: 'godwinson',
#  355: 'an',
#  1260: 'extremely',
#  1107: 'down',
#  3527: 'with',
#  3240: 'trail',
#  2897: 'smok',
#  175: '44counted',
#  32: '15',
#  2315: 'orbs',
#  3352: 'until',
#  3384: 'vanished',
#  655: 'bursts',
#  819: 'color',
#  849: 'concentrated',
#  402: 'area',
#  800: 'cloud',
#  509: 'beautiful',
#  2845: 'silver',
#  821: 'colored',
#  2715: 'saucer',
#  273: 'about',
#  2866: 'size',
#  2681: 'round',
#  44: '18',
#  3482: 'wheeler',
#  3300: 'turquoise',
#  2412: 'perimeter',
#  786: 'clearly',
#  131: '3997',
#  8: '05',
#  240: '64',
#  4: '02',
#  0: '00',
#  1908: 'little',
#  921: 'creek',
#  1819: 'ky',
#  1644: 'humming',
#  2199: 'noise',
#  1621: 'house',
#  2791: 'shaking',
#  2894: 'small',
#  2019: 'medium',
#  2867: 'sized',
#  560: 'black',
#  2596: 'rectangular',
#  2784: 'several',
#  3563: 'years',
#  3263: 'tree',
#  1899: 'line',
#  1325: 'fireball',
#  2659: 'rising',
#  2347: 'over',
#  1081: 'distant',
#  2671: 'rooftops',
#  3046: 'straight',
#  3358: 'up',
#  335: 'almost',
#  1619: 'hour',
#  567: 'blending',
#  3007: 'stars',
#  2758: 'seemingly',
#  654: 'burning',
#  3120: 'tail',
#  1078: 'dissipated',
#  3225: 'towards',
#  1189: 'end',
#  2835: 'sight',
#  548: 'big',
#  2075: 'miss',
#  200: '44orange',
#  2600: 'redish',
#  2250: 'objects',
#  1367: 'floating',
#  1604: 'home',
#  2780: 'sets',
#  3306: 'two',
#  3088: 'sunset',
#  2610: 'remained',
#  3487: 'while',
#  2329: 'other',
#  2122: 'moved',
#  2942: 'southwest',
#  3021: 'stayed',
#  3285: 'tripled',
#  2862: 'sitting',
#  699: 'car',
#  1932: 'looking',
#  2852: 'singal',
#  1196: 'engine',
#  2448: 'plane',
#  3080: 'suddenly',
#  1058: 'disc',
#  3464: 'went',
#  2381: 'past',
#  3405: 'very',
#  3490: 'white',
#  735: 'chased',
#  233: '52',
#  2166: 'near',
#  3553: 'wright',
#  2392: 'patterson',
#  309: 'air',
#  1388: 'force',
#  489: 'base',
#  2494: 'power',
#  2336: 'out',
#  679: 'came',
#  2756: 'seemed',
#  769: 'circle',
#  831: 'come',
#  464: 'back',
#  2544: 'quickly',
#  1786: 'just',
#  3383: 'vanishe',
#  3179: 'thirteen',
#  2148: 'my',
#  1498: 'grandmother',
#  2109: 'mother',
#  1549: 'having',
#  1665: 'ice',
#  919: 'cream',
#  2342: 'outside',
#  1033: 'diner',
#  219: '45',
#  228: '50',
#  989: 'degrees',
#  1478: 'glows',
#  730: 'changing',
#  1022: 'different',
#  307: 'again',
#  3566: 'yellow',
#  1628: 'hovering',
#  1004: 'description',
#  2487: 'possible',
#  2837: 'sighting',
#  3032: 'still',
#  2498: 'present',
#  3002: 'star',
#  3209: 'together',
#  2700: 'same',
#  2959: 'speed',
#  1030: 'dimmed',
#  1051: 'disappeared',
#  1344: 'flare',
#  746: 'chevron',
#  2842: 'silent',
#  2062: 'min',
#  710: 'caught',
#  3413: 'video',
#  3134: 'tape',
#  304: 'after',
#  1305: 'few',
#  1507: 'greenish',
#  1013: 'diamond',
#  1334: 'five',
#  2895: 'smaller',
#  971: 'daytime',
#  1006: 'desert',
#  1627: 'hovered',
#  2957: 'sped',
#  460: 'away',
#  2078: 'mississauga',
#  685: 'canada',
#  386: 'appeared',
#  500: 'be',
#  1586: 'high',
#  2488: 'possibly',
#  375: 'any',
#  1144: 'earthling',
#  1963: 'made',
#  1749: 'item',
#  1686: 'incredible',
#  1352: 'flat',
#  574: 'blinking',
#  1825: 'lake',
#  2328: 'oswego',
#  2549: 'quot',
#  1423: 'full',
#  2822: 'shortly',
#  21: '11',
#  37: '16',
#  985: 'defied',
#  299: 'aerodynamiccs',
#  1814: 'know',
#  579: 'blue',
#  2532: 'purple',
#  1270: 'faded',
#  950: 'danced',
#  925: 'cricle',
#  2657: 'rise',
#  1055: 'disapper',
#  2638: 'retiring',
#  1491: 'got',
#  517: 'bed',
#  2672: 'room',
#  952: 'dark',
#  3509: 'window',
#  2884: 'slightly',
#  2295: 'open',
#  1556: 'head',
#  1866: 'left',
#  1436: 'gateway',
#  316: 'airport',
#  2029: 'merged',
#  370: 'anouther',
#  512: 'became',
#  3197: 'tight',
#  210: '44straight',
#  392: 'approx',
#  130: '39',
#  2793: 'shape',
#  1708: 'intense',
#  1138: 'each',
#  807: 'cntr',
#  204: '44rest',
#  1380: 'followed',
#  2259: 'observer',
#  3035: 'stoppe',
#  643: 'brownwood',
#  3155: 'texas',
#  123: '33',
#  1389: 'forest',
#  1444: 'germany',
#  2772: 'september',
#  251: '7pm',
#  3416: 'view',
#  2070: 'minute',
#  2005: 'mass',
#  2975: 'sporadically',
#  1685: 'inconsistent',
#  2933: 'sounds',
#  3453: 'waves',
#  110: '29',
#  159: '442008',
#  257: '8pm',
#  194: '44my',
#  3576: 'yr',
#  2284: 'old',
#  1457: 'girls',
#  426: 'asked',
#  3478: 'what',
#  1670: 'if',
#  2816: 'shooting',
#  3211: 'told',
#  3161: 'them',
#  3000: 'standing',
#  2670: 'roof',
#  379: 'apartment',
#  785: 'clear',
#  3085: 'sunny',
#  968: 'day',
#  3535: 'wobbeling',
#  286: 'accross',
#  3184: 'thought',
#  556: 'bird',
#  2127: 'moves',
#  528: 'being',
#  1065: 'disk',
#  1307: 'field',
#  247: '70',
#  139: '39s',
#  2376: 'pass',
#  2454: 'play',
#  734: 'chase',
#  384: 'appear',
#  342: 'altitude',
#  191: '44make',
#  1049: 'disappear',
#  1297: 'feeding',
#  1480: 'goat',
#  1930: 'looked',
#  2548: 'quite',
#  1923: 'long',
#  3174: 'thin',
#  2349: 'overhead',
#  1529: 'hammond',
#  1672: 'illinois',
#  3113: 'sylvania',
#  2012: 'mccord',
#  1782: 'junior',
#  2337: 'outer',
#  2945: 'space',
#  81: '20',
#  1347: 'flash',
#  626: 'brightlights',
#  354: 'amp',
#  3461: 'weird',
#  2202: 'noisies',
#  3048: 'strange',
#  1540: 'happennings',
#  3437: 'walking',
#  1917: 'local',
#  480: 'bar',
#  2001: 'mars',
#  513: 'because',
#  684: 'can',
#  3462: 'well',
#  2653: 'right',
#  2231: 'now',
#  2525: 'pulsating',
#  544: 'bethel',
#  2368: 'park',
#  2354: 'pa',
#  756: 'christmas',
#  1225: 'eve',
#  2701: 'san',
#  374: 'antonio',
#  680: 'camera',
#  987: 'definitely',
#  896: 'could',
#  1669: 'idetify',
#  3180: 'this',
#  2317: 'ordinary',
#  1361: 'flies',
#  2843: 'silently',
#  1227: 'evening',
#  2459: 'please',
#  2632: 'respect',
#  2507: 'privacy',
#  728: 'changed',
#  1041: 'directions',
#  1247: 'experience',
#  3346: 'unkown',
#  3395: 'vegas',
#  691: 'cant',
#  1249: 'explain',
#  1484: 'golden',
#  1471: 'globe',
#  1239: 'executing',
#  2554: 'radical',
#  1988: 'manuvers',
#  282: 'accelerating',
#  895: 'couch',
#  2740: 'screen',
#  1099: 'door',
#  1539: 'happened',
#  2753: 'see',
#  314: 'airplane',
#  659: 'but',
#  798: 'closer',
#  2311: 'orb',
#  486: 'barnes',
#  2571: 'rd',
#  3438: 'wallingford',
#  2343: 'oval',
#  580: 'blueish',
#  3586: 'zig',
#  3583: 'zaging',
#  1073: 'dissapears',
#  3044: 'strage',
#  2279: 'ohio',
#  2661: 'river',
#  2886: 'slow',
#  2955: 'spectacular',
#  3276: 'triangle',
#  2755: 'seem',
#  2741: 'se',
#  1016: 'did',
#  2121: 'move',
#  1152: 'eastern',
#  2564: 'random',
#  2527: 'pulse',
#  3471: 'western',
#  2158: 'nassau',
#  469: 'bahamas',
#  2230: 'november',
#  105: '25',
#  94: '2012',
#  310: 'aircraft',
#  2502: 'pressure',
#  3452: 'wave',
#  308: 'ahead',
#  1192: 'endur',
#  114: '3000',
#  396: 'aprox',
#  2238: 'nw',
#  1506: 'green',
#  3069: 'strobing',
#  1132: 'duration',
#  2234: 'nuforc',
#  2222: 'note',
#  2854: 'sirius',
#  2395: 'pd',
#  532: 'bell',
#  1071: 'dissapear',
#  2583: 'reappear',
#  2094: 'monmouth',
#  902: 'county',
#  2180: 'new',
#  1763: 'jersey',
#  1990: 'maple',
#  1518: 'grove',
#  382: 'apparent',
#  1328: 'firey',
#  600: 'bottom',
#  2424: 'photos',
#  698: 'captured',
#  1126: 'drops',
#  1847: 'late',
#  305: 'afternoon',
#  2561: 'raleigh',
#  2164: 'nc',
#  395: 'april',
#  258: '8th',
#  2334: 'our',
#  1939: 'lost',
#  2105: 'morphed',
#  1052: 'disappearing',
#  2979: 'spotted',
#  828: 'columbus',
#  2133: 'ms',
#  2055: 'military',
#  311: 'aircrafts',
#  387: 'appearing',
#  1726: 'investigate',
#  1509: 'grey',
#  1412: 'friend',
#  1290: 'fashion',
#  2834: 'sideways',
#  1037: 'direct',
#  942: 'cylinder',
#  3024: 'steady',
#  1550: 'hawk',
#  3217: 'top',
#  947: 'dad',
#  1424: 'future',
#  467: 'backyard',
#  2908: 'soaring',
#  1350: 'flashing',
#  1216: 'erratically',
#  1947: 'low',
#  102: '22',
#  1561: 'headlights',
#  719: 'centered',
#  25: '13',
#  148: '40',
#  2988: 'squared',
#  3406: 'vessel',
#  1962: 'macon',
#  1428: 'ga',
#  2362: 'paper',
#  1775: 'journal',
#  3013: 'stated',
#  2098: 'month',
#  2709: 'satalites',
#  3424: 'visible',
#  145: '39winking',
#  886: 'corner',
#  1197: 'england',
#  3313: 'ufos',
#  731: 'charleston',
#  2724: 'sc',
#  3056: 'streaming',
#  2966: 'spheres',
#  997: 'des',
#  2087: 'moines',
#  1735: 'iowa',
#  476: 'balls',
#  1394: 'formations',
#  1766: 'jets',
#  3224: 'toward',
#  1793: 'kennedy',
#  718: 'center',
#  3417: 'viewed',
#  812: 'cocoa',
#  1336: 'fl',
#  1477: 'glowing',
#  499: 'bday',
#  2374: 'party',
#  1172: 'else',
#  346: 'am',
#  2623: 'reporting',
#  1521: 'gulf',
#  425: 'ashtabula',
#  2856: 'sister',
#  639: 'brother',
#  1853: 'law',
#  1542: 'hard',
#  3188: 'three',
#  3076: 'suburb',
#  1324: 'fire',
#  534: 'beloit',
#  3496: 'wi',
#  596: 'border',
#  2396: 'pea',
#  2463: 'pod',
#  1401: 'four',
#  1887: 'lighted',
#  2399: 'peas',
#  3532: 'witnessed',
#  3201: 'times',
#  3269: 'tremendeous',
#  1215: 'erratic',
#  2123: 'moveme',
#  3254: 'travel',
#  2214: 'northern',
#  1369: 'florida',
#  2530: 'pulsing',
#  2823: 'shot',
#  2666: 'rocket',
#  3347: 'unlike',
#  2043: 'mi',
#  2931: 'soundless',
#  2864: 'six',
#  3182: 'those',
#  490: 'baseball',
#  3067: 'strobe',
#  1864: 'lebanon',
#  934: 'ct',
#  142: '39taking',
#  1047: 'disapearing',
#  2742: 'sea',
#  1079: 'distance',
#  1658: 'i4',
#  1243: 'exit',
#  30: '14',
#  2967: 'spherical',
#  1527: 'halo',
#  398: 'arc',
#  2612: 'remember',
#  2358: 'pale',
#  1133: 'durham',
#  1381: 'following',
#  1039: 'direction',
#  1906: 'lite',
#  3191: 'through',
#  620: 'brie',
#  1283: 'far',
#  1473: 'glod',
#  2225: 'nothig',
#  3572: 'you',
#  2136: 'much',
#  2186: 'nice',
#  2027: 'mercey',
#  1617: 'hot',
#  2984: 'springs',
#  2970: 'spinning',
#  2914: 'solid',
#  2811: 'shinny',
#  3251: 'transparent',
#  2976: 'spot',
#  1559: 'heading',
#  2306: 'orangeish',
#  1396: 'forming',
#  939: 'curved',
#  1524: 'had',
#  2922: 'somewhere',
#  717: 'cen',
#  38: '160',
#  2102: 'more',
#  3309: 'type',
#  1395: 'formed',
#  2751: 'seconds',
#  3455: 'way',
#  1888: 'lighthouse',
#  1089: 'does',
#  1095: 'doing',
#  3105: 'swarm',
#  521: 'bees',
#  1984: 'manouvers',
#  764: 'cigar',
#  2015: 'me',
#  1167: 'electric',
#  1690: 'indian',
#  701: 'carolina',
#  2378: 'passenger',
#  2745: 'seat',
#  882: 'conversion',
#  3379: 'van',
#  2090: 'mom',
#  2831: 'siblings',
#  427: 'asleep',
#  1182: 'emitted',
#  969: 'daylight',
#  2694: 'rush',
#  1503: 'gray',
#  461: 'awesome',
#  3569: 'yet',
#  922: 'creepy',
#  2974: 'spooky',
#  2806: 'shined',
#  2808: 'shiniest',
#  757: 'chrome',
#  1233: 'ever',
#  843: 'completely',
#  2545: 'quiet',
#  2836: 'sighted',
#  1842: 'las',
#  2621: 'report',
#  1230: 'event',
#  3463: 'wells',
#  211: '44texas',
#  3530: 'without',
#  113: '300',
#  149: '400',
#  1298: 'feet',
#  2418: 'phoenix',
#  463: 'az',
#  2303: 'orage',
#  1464: 'glenville',
#  3557: 'wv',
#  1629: 'hovers',
#  1624: 'houston',
#  3307: 'tx',
#  1278: 'fall',
#  62: '1973',
#  2977: 'spotlight',
#  2080: 'mist',
#  3363: 'upward',
#  2111: 'motion',
#  2076: 'missile',
#  1850: 'launch',
#  214: '44then',
#  2304: 'orang',
#  3450: 'watching',
#  2119: 'mountain',
#  1282: 'fanwood',
#  2195: 'nj',
#  2775: 'series',
#  2943: 'southwestern',
#  3139: 'teardrop',
#  3451: 'water',
#  1905: 'lit',
#  1356: 'flew',
#  599: 'bothell',
#  3429: 'wa',
#  2035: 'metallic',
#  1088: 'dodge',
#  3058: 'street',
#  1257: 'exprsway',
#  2286: 'omaha',
#  2165: 'ne',
#  1554: 'hbccufo',
#  686: 'canadian',
#  1017: 'didn',
#  141: '39t',
#  3095: 'surrounded',
#  2176: 'neon',
#  1625: 'hover',
#  955: 'dart',
#  2007: 'massive',
#  822: 'colorful',
#  1701: 'instantly',
#  1589: 'highway',
#  118: '31',
#  1691: 'indiana',
#  999: 'descend',
#  3265: 'trees',
#  1590: 'hill',
#  1042: 'directly',
#  3401: 'vernon',
#  1475: 'glowball',
#  1419: 'front',
#  519: 'bedroom',
#  1300: 'felt',
#  660: 'butterfly',
#  2765: 'sensation',
#  745: 'chest',
#  3156: 'th',
#  433: 'atlantic',
#  2267: 'ocean',
#  811: 'coastal',
#  1599: 'hobe',
#  2044: 'miami',
#  328: 'alien',
#  2458: 'playing',
#  1399: 'forth',
#  1164: 'egg',
#  5: '03',
#  1820: 'l7',
#  1620: 'hours',
#  3386: 'vanishing',
#  1863: 'leaving',
#  585: 'bobbing',
#  3345: 'unknown',
#  3303: 'twinkling',
#  887: 'corners',
#  3328: 'underneath',
#  412: 'arou',
#  2440: 'pinkish',
#  2656: 'rings',
#  1115: 'drifting',
#  2135: 'mt',
#  3374: 'va',
#  2491: 'potomac',
#  1142: 'early',
#  52: '1963',
#  53: '1964',
#  2615: 'reno',
#  3060: 'streets',
#  3289: 'trying',
#  1319: 'find',
#  1618: 'hotel',
#  2228: 'noticed',
#  2431: 'pie',
#  1536: 'hanging',
#  775: 'circus',
#  2369: 'parki',
#  59: '197',
#  1557: 'headed',
#  3546: 'work',
#  1610: 'horizion',
#  2428: 'pics',
#  980: 'decide',
#  3574: 'yourself',
#  1800: 'kid',
#  315: 'airplanes',
#  1226: 'even',
#  2713: 'satllites',
#  2184: 'next',
#  3200: 'time',
#  2072: 'minuts',
#  589: 'bolingbrook',
#  2009: 'may',
#  43: '17th',
#  84: '2001',
#  2017: 'meadows',
#  1868: 'length',
#  3314: 'uk',
#  1358: 'flickered',
#  2619: 'replace',
#  3070: 'strong',
#  2356: 'pacific',
#  1897: 'lincoln',
#  1523: 'gypsy',
#  501: 'beach',
#  834: 'coming',
#  3259: 'travels',
#  423: 'ascends',
#  1467: 'gliding',
#  1980: 'manhattan',
#  1034: 'dinner',
#  2916: 'some',
#  897: 'couldn',
#  527: 'beileve',
#  1937: 'los',
#  360: 'angeles',
#  1992: 'march',
#  86: '2004',
#  1771: 'johannesburg',
#  303: 'africa',
#  1292: 'faster',
#  377: 'anything',
#  1279: 'falling',
#  1359: 'flickering',
#  3354: 'untli',
#  1318: 'finally',
#  3089: 'super',
#  2981: 'spped',
#  2138: 'multi',
#  825: 'coloured',
#  565: 'blasts',
#  2804: 'shifting',
#  3107: 'swaying',
#  96: '2055',
#  1633: 'hrs',
#  1161: 'edt',
#  2853: 'single',
#  3270: 'tremendously',
#  1254: 'explodes',
#  292: 'activity',
#  1791: 'keller',
#  2711: 'satellites',
#  429: 'associated',
#  741: 'chemtrails',
#  3255: 'traveled',
#  3356: 'unusual',
#  1983: 'manner',
#  2464: 'point',
#  3584: 'zags',
#  1935: 'loops',
#  2067: 'minnesotas',
#  3544: 'woods',
#  2168: 'nearly',
#  1208: 'equilateral',
#  3221: 'total',
#  2844: 'sillouette',
#  2830: 'si',
#  1673: 'illuminated',
#  1066: 'disks',
#  2120: 'mountains',
#  1339: 'flame',
#  2212: 'northeast',
#  1919: 'location',
#  1443: 'georgia',
#  1259: 'extreme',
#  3291: 'tubular',
#  992: 'delta',
#  598: 'both',
#  976: 'debris',
#  2838: 'sightings',
#  1808: 'kingstown',
#  2647: 'ri',
#  2270: 'odd',
#  1875: 'lewisville',
#  2691: 'running',
#  1856: 'leader',
#  2693: 'rural',
#  3153: 'tests',
#  2912: 'soil',
#  1422: 'fuel',
#  714: 'cell',
#  3387: 'vapor',
#  1093: 'dogs',
#  484: 'barking',
#  1943: 'loudly',
#  1342: 'flanked',
#  2290: 'ones',
#  2858: 'sited',
#  2433: 'pier',
#  2394: 'pawleys',
#  1743: 'island',
#  514: 'become',
#  439: 'auburn',
#  1296: 'federal',
#  1952: 'luminous',
#  2444: 'pittsburgh',
#  3562: 'year',
#  1082: 'distinct',
#  2155: 'naked',
#  1261: 'eye',
#  729: 'changes',
#  408: 'arm',
#  3579: 'yuma',
#  2124: 'movement',
#  3519: 'winn',
#  1086: 'dixie',
#  2370: 'parking',
#  1940: 'lot',
#  1926: 'longwood',
#  3488: 'whippany',
#  2107: 'morris',
#  1843: 'last',
#  2900: 'smoking',
#  766: 'cigarette',
#  345: 'always',
#  1087: 'do',
#  2618: 'repeated',
#  1188: 'encounter',
#  67: '1980',
#  ...}

# %%
ufo1 = ufo[['seconds_log', 'changing', 'chevron', 'cigar', 'circle', 'cone', 'cross', 'cylinder', 'diamond', 'disk', 'egg', 'fireball', 'flash', 'formation', 'light', 'other', 'oval', 'rectangle',
       'sphere', 'teardrop', 'triangle', 'unknown', 'month', 'year','country_enc']]
ufo1.dropna(how='any', inplace=True)
X = ufo1.drop(columns=['country_enc'], axis=1)
y = np.array(ufo1['country_enc'])
# Take a look at the features in the X set of data


print(X.columns)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
knn = KNeighborsClassifier()
# Split the X and y sets
# Take a look at the features in the X set of data
print(X.columns)

# Split the X and y sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# Fit knn to the training sets
knn.fit(X_train, y_train)

# Print the score of knn on the test sets
print(knn.score(X_test, y_test))
# Out:
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Index(['seconds_log', 'changing', 'chevron', 'cigar', 'circle', 'cone',
#        'cross', 'cylinder', 'diamond', 'disk', 'egg', 'fireball', 'flash',
#        'formation', 'light', 'other', 'oval', 'rectangle', 'sphere',
#        'teardrop', 'triangle', 'unknown', 'month', 'year'],
#       dtype='object')
# Index(['seconds_log', 'changing', 'chevron', 'cigar', 'circle', 'cone',
#        'cross', 'cylinder', 'diamond', 'disk', 'egg', 'fireball', 'flash',
#        'formation', 'light', 'other', 'oval', 'rectangle', 'sphere',
#        'teardrop', 'triangle', 'unknown', 'month', 'year'],
#       dtype='object')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_35756/1517768110.py in <module>
#      23
#      24 # Print the score of knn on the test sets
# ---> 25 print(knn.score(X_test, y_test))
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     703         from .metrics import accuracy_score
#     704
# --> 705         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     706
#     707     def _more_tags(self):
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     244         check_is_fitted(self, "_fit_method")
#     245         if self.weights == "uniform":
# --> 246             if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     247                 X, self._fit_X, self.metric
#     248             ):
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py in is_usable_for(cls, X, Y, metric)
#     469         """
#     470         return (
# --> 471             ArgKmin.is_usable_for(X, Y, metric)
#     472             # TODO: Support CSR matrices.
#     473             and not issparse(X)
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py in is_usable_for(cls, X, Y, metric)
#     113         is_usable = (
#     114             get_config().get("enable_cython_pairwise_dist", True)
# --> 115             and (is_numpy_c_ordered(X) or is_valid_sparse_matrix(X))
#     116             and (is_numpy_c_ordered(Y) or is_valid_sparse_matrix(Y))
#     117             and X.dtype == Y.dtype
#
# c:\Users\jdamodhar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_pairwise_distances_reduction\_dispatcher.py in is_numpy_c_ordered(X)
#      97
#      98         def is_numpy_c_ordered(X):
# ---> 99             return hasattr(X, "flags") and X.flags.c_contiguous
#     100
#     101         def is_valid_sparse_matrix(X):
#
# AttributeError: 'Flags' object has no attribute 'c_contiguous'

# %%
import sklearn.naive_bayes as GaussianNB


nb=GaussianNB()
# Use the list of filtered words we created to filter the text vector
filtered_text = desc_tfidf[:, list(filtered_words)]

# Split the X and y sets using train_test_split, setting stratify=y 
X_train, X_test, y_train, y_test = train_test_split(filtered_text.toarray(), y, stratify=y, random_state=42)

# Fit nb to the training sets
nb.fit(X_train, y_train)

# Print the score of nb on the test sets
print(nb.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JDAMOD~1\AppData\Local\Temp/ipykernel_35756/141398422.py in <module>
#       2
#       3
# ----> 4 nb=GaussianNB()
#       5 # Use the list of filtered words we created to filter the text vector
#       6 filtered_text = desc_tfidf[:, list(filtered_words)]
#
# TypeError: 'module' object is not callable
