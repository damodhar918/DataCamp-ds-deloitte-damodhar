# %%
# !pytest -rsx
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items
#
# features\test_as_numpy.py s..............                                [ 78%]
# models\test_train.py ..xx                                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items
#
# features\test_as_numpy.py s..............                                [ 78%]
# models\test_train.py ..xx                                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest -rs
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items
#
# features\test_as_numpy.py s..............                                [ 78%]
# models\test_train.py ..xx                                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest -rx
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items
#
# features\test_as_numpy.py s..............                                [ 78%]
# models\test_train.py ..xx                                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest --cov=features --cov=models --cov-report=html
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items
#
# features\test_as_numpy.py s..............                                [ 78%]
# models\test_train.py ..xx                                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest -k SplitInto
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items / 17 deselected / 2 selected
#
# models\test_train.py ..                                                  [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest -W error::UserWarning
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items
#
# features\test_as_numpy.py s..............                                [ 78%]
# models\test_train.py ..xx                                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest -x
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1
# rootdir: c:\Users\jdamodhar\Desktop\python_essential-\DataCamp-ds-deloitte-master\00-A\23-Unit Testing for Data Science in Python\03-Test Organization and Execution
# plugins: anyio-2.2.0, cov-4.1.0
# collected 19 items
#
# features\test_as_numpy.py s..............                                [ 78%]
# models\test_train.py ..xx                                                [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\..\..\..\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
#   C:\Users\jdamodhar\Anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.10 it will stop working
#     return isinstance(x, collections.Callable)
#
# ...

# %%
# !pytest --help
# Out:
# usage: pytest [options] [file_or_dir] [file_or_dir] [...]
#
# positional arguments:
#   file_or_dir
#
# general:
#   -k EXPRESSION         only run tests which match the given substring
#                         expression. An expression is a python evaluatable
#                         expression where all names are substring-matched against
#                         test names and their parent classes. Example: -k
#                         'test_method or test_other' matches all test functions
#                         and classes whose name contains 'test_method' or
#                         'test_other', while -k 'not test_method' matches those
#                         that don't contain 'test_method' in their names. -k 'not
#                         test_method and not test_other' will eliminate the
#                         matches. Additionally keywords are matched to classes
#                         and functions containing extra names in their
# ...
