# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# # Sales Records Dataset
#
# The following dataset contains records of sales in pet supply stores from the previous year.
#
# ## Data Source
#
# The dataset can be accessed and downloaded from the following link: https://s3.amazonaws.com/talent-assets.datacamp.com/pet_supplies_2212.csv
#
# ## Description
#
# The dataset includes the following columns:
#
# - `InvoiceNo`: The invoice number of the sale
# - `StockCode`: The stock code of the product
# - `Description`: A brief description of the product
# - `Quantity`: The quantity of the product sold
# - `InvoiceDate`: The date of the sale
# - `UnitPrice`: The unit price of the product in pounds
# - `CustomerID`: The ID of the customer who made the purchase
# - `Country`: The country where the sale was made
#
# ## Format
#
# The dataset is in CSV format and includes a header row. It can be opened and analyzed in various software packages including Excel, Python, and R.
#
#
# |Column Name | Criteria                                                                                                                                                                                    |
# |-------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | product_id  | Nominal. The unique identifier of the product. Missing values are not possible due to the database structure.                                                                              |
# | category    | Nominal. The category of the product, one of 6 values (Housing, Food, Toys, Equipment, Medicine, Accessory). Missing values should be replaced with “Unknown”.                               |
# | animal      | Nominal. The type of animal the product is for. One of Dog, Cat, Fish, Bird. Missing values should be replaced with “Unknown”.                                                                 |
# | size        | Ordinal. The size of animal the product is for. Small, Medium, Large. Missing values should be replaced with “Unknown”.                                                                        |
# | price       | Continuous. The price the product is sold at. Can be any positive value, round to 2 decimal places. Missing values should be replaced with the overall median price.                           |
# | sales       | Continuous. The value of all sales of the product in the last year. This can be any positive value, rounded to 2 decimal places. Missing values should be replaced with the overall median sales. |
# | rating      | Discrete. Customer rating of the product from 1 to 10. Missing values should be replaced with 0.                                                                                               |
# | repeat_purchase | Nominal. Whether customers repeatedly buy the product (1) or not (0). Missing values should be removed.                                                                                    |

# %% [markdown]
# ## Task 1

# %%
# Import necessary libraries for data analysis and visualization
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("pet_supplies_2212.csv")
print("Columns : ",end='')
print(*df.columns,sep=', ')
df
# product_id,category,animal,size,price,sales,rating,repeat_purchase
# Out:
# Columns : product_id, category, animal, size, price, sales, rating, repeat_purchase
#       product_id   category animal  ...    sales rating  repeat_purchase
# 0              1       Food   Bird  ...  1860.62    7.0                1
# 1              2    Housing   Bird  ...   963.60    6.0                0
# 2              3       Food    Dog  ...   898.30    5.0                1
# 3              4   Medicine    Cat  ...   982.15    6.0                1
# 4              5    Housing    Cat  ...   832.63    7.0                1
# ...          ...        ...    ...  ...      ...    ...              ...
# 1495        1496       Food   Bird  ...  1203.36    5.0                0
# 1496        1497  Equipment    Dog  ...  1099.97    5.0                0
# 1497        1498       Food   Fish  ...   724.02    3.0                0
# 1498        1499   Medicine   Fish  ...   658.66    5.0                1
# 1499        1500       Food    Cat  ...   826.08    4.0                1
#
# ...

# %% [markdown]
# For every column in the data:
#
# a. State whether the values match the description given in the table above.
#
#   Here is a more detailed analysis, based on the information provided:
#
# - `product_id` is indeed unique and appears to be of the integer data type.
# - `category` has a value of "-" in some rows, which suggests missing or unknown data. In such cases, it would be appropriate to replace "-" with "Unknown" or NaN.
# - `animal` is categorical and seems to have the appropriate values of Dog, Cat, Fish and Bird.
# - `size` has inconsistent formatting with values like "Medium", "medium", and "MEDIUM". This will need to be standardized to one consistent format such as all caps or all lowercase.
# - `price` appears to be of object data type, which could indicate that it contains non-numerical values or that it needs to be coerced into a numeric type. Furthermore, it will need to be rounded to two decimal places.
# - `sales` appears to be fine and has float data type.
# - `rating` has some missing values that will need to be replaced with zeros.
# - `repeat_purchase` is binary and appears to have the values 0 and 1, which is appropriate for a boolean-type variable.
#
#     Based on these observations, it seems that there might be some data cleaning and preprocessing that needs to be performed before conducting any further analysis on the data.
#
# b. State the number of missing values in the column.
# Based on the given data and info, the number of missing values in each column is:
#
# - `product_id`: 0 missing values
# - `category`: 0 missing values
# - `animal`: 0 missing values
# - `size`: 0 missing values
# - `price`: 0 missing values. However, it has issues regarding the data type as it should be converted to float or int data type for numerical calculations.
# - `sales`: 0 missing values
# - `rating`: 150 missing values
# - `repeat_purchase`: 0 missing values
# C. Describe what you did to make values match the description if they did not
# match.
#
# framework for cleaning and preparing data to match the given description. Here are some steps that you can perform to ensure that the data matches the given description:
#
# 1. Check for missing or null values in the dataset: Use the `isnull()` method to identify missing or null values in the dataset. If null values are identified, you can either fill in the missing values with appropriate data if possible or drop the null values depending on the nature of the data.
# 2. Check data types: Ensure that the data types for each column align with the given description of the dataset. Use the `dtypes` method to display the data types for each column, and modify them as needed using the `astype()` method or other methods to coerce the data to the intended data type.
# 3. Clean up data inconsistencies: If there are inconsistencies in the data, like inconsistent capitalization or spelling errors, you can normalize the data to resolve these inconsistencies. For example, you can use the `str` accessor methods in Pandas to convert data to lower or upper case, or to perform string operations that remove redundant spaces or characters.
# 4. Address outliers: For numerical data, you can use descriptive statistics to identify outliers in the data. Outliers can then be removed or treated using statistical methods like the Interquartile Range (IQR) to ensure accuracy of the data.
# 5. Merge disjoint values: If a column contains disjoint values, you can merge them to align with the given description. For example, if a column contains dates in different formats, you can standardize all dates to one format.
# 6. Subsetting Data: For large datasets, it may be necessary to subset the data based on criteria provided in the description. In this case, utilize the `loc` method in Pandas to extract the subset of data that meet this criteria.
#
# By following these steps, you can clean and prepare the data to match the given description. You can then perform desired data analysis and visualization on the cleaned dataset.

# %% [markdown]
# ## Task 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar chart of the count of repeat and non-repeat purchases by category
sns.countplot(x='category', hue='repeat_purchase', data=df)

# Set the chart title and axes labels
plt.title('Count of Repeat and Non-Repeat Purchases by Category')
plt.xlabel('Category')
plt.ylabel('Count')

# Display the
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Create a visualization that shows how many products are repeat purchases. Use the visualization to:
#
# a. State which category of the variable repeat purchases has the most
# observation
#
# -    Based on the data you provided, the Equipment category has the most observations of repeat purchases, with 221 observations.
# -    code and visual available in below cell.
#
# b. Explain whether the observations are balanced across categories of the
# variable repeat purchases
#
# -    The observations are not balanced across categories of the variable . Some categories have a much higher count of observations than others.
# -    For example, the Equipment category has the highest number of observations, with a total of 370 (221 for repeat purchases and 149 for non-repeat purchases). In contrast, the '-' category has only 25 total observations (14 for repeat purchases and 11 for non-repeat purchases).
# -    This imbalance in observations across categories is important to keep in mind when analyzing the data and drawing conclusions. It's possible that conclusions based on categories with fewer observations may not be as reliable or valid as those based on categories with more observations.

# %% [markdown]
# ## Task 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a histogram plot of all sales
sns.histplot(data=df, x='sales')

# Set the chart title and axes labels
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')

# Display the chart
plt.show()

# %% [markdown]
# Describe the distribution of all of the sales. Your answer must include a visualization
# that shows the distribution.
#
# - visual provided in above cell, histogram plot that shows the distribution of sales. The x-axis will show the range of sales, and the y-axis will show the frequency count of sales falling in each bin.
# - higest sales is 1000 bin with 250 frequency which is look like negetive skew

# %% [markdown]
# ## Task 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a box plot of repeat purchases versus sales
sns.boxplot(data=df, x='repeat_purchase', y='sales')

# Set the chart title and axes labels
plt.title('Relationship between Repeat Purchases and Sales')
plt.xlabel('Repeat Purchases')
plt.ylabel('Sales')

# Display the chart
plt.show()

# %% [markdown]
# Describe the relationship between repeat purchases and sales. Your answer must
# include a visualization to demonstrate the relationship.
#
# - This code will create a box plot that shows the relationship between repeat purchases and sales. The x-axis will show whether a purchase was a repeat purchase or not, and the y-axis will show the corresponding sales amount.
# - The box plot will show if there are any significant differences in the distribution of sales amount for repeat purchases compared to non-repeat purchases. We can also use additional visual features in the box plot, such as colors or markers, to differentiate between different categories or attributes of the data.
# - In quick,higher sales has lower repeat purchases  chance

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
